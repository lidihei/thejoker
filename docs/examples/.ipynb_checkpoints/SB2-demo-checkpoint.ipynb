# %% [markdown]
# This requires installing an experimental branch of `thejoker`:
#
#     pip install git+https://github.com/adrn/thejoker@sb2

# %%
import os

from astropy.time import Time
import astropy.units as u
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from twobody import KeplerOrbit, TwoBodyKeplerElements
import pymc as pm

import thejoker as tj

plt.style.use('lijiaonature')

# %%
import astropy
import numpy
print(astropy.__version__)
print(numpy.__version__)

# %% [markdown]
# Generate fake data. This implementation requires that you can assign RV measurements to each binary star component:

# %%
n_data1 = 5
n_data2 = 3

rnd = np.random.RandomState(42)
t0 = Time('J2000') + rnd.uniform(0., 20) * u.day

truth1 = dict()
truth1['P'] = rnd.uniform(40, 80) * u.day
truth1['M0'] = rnd.uniform(0., 2*np.pi) * u.radian
truth1['omega'] = rnd.uniform(0., 2*np.pi) * u.radian
truth1['e'] = 0.2
truth1['K'] = rnd.uniform(5, 15) * u.km/u.s
truth1['v0'] = rnd.uniform(-10, 10) * u.km/u.s

elem = TwoBodyKeplerElements(P=truth1['P'], e=truth1['e'], omega=truth1['omega'],
                             M0=truth1['M0'], t0=t0, m1=1*u.Msun, m2=0.4*u.Msun,
                             i=90*u.deg, Omega=51*u.deg)  # these don't matter

# %%
truth1['P']

# %% [markdown]
# Pack the fake data into a dictionary (required with the current API):

# %%
orbit1 = KeplerOrbit(elem.primary)
orbit2 = KeplerOrbit(elem.secondary)

t1 = t0 + truth1['P'] * np.sort(rnd.uniform(0, 5, n_data1))
t2 = t0 + truth1['P'] * np.sort(rnd.uniform(0, 5, n_data2))

datas = {}
for name, t, orbit in zip(['1', '2'], [t1, t2], [orbit1, orbit2]):
    rv = orbit.radial_velocity(t) + truth1['v0']
    err = np.full_like(rv.value, 5.) * u.km/u.s
    data = tj.RVData(t, rv, rv_err=err, t_ref=t0)
    datas[name] = data
    
datas

# %% [markdown]
# Plot the fake data:

# %%
datas['1'].plot(color='tab:blue')  # primary
datas['2'].plot(color='tab:red')  # secondary

# %%
orbit1.radial_velocity(t1)

# %%
t1

# %%
import thejoker.units as xu
with pm.Model() as model:
    dv0_1 = xu.with_unit(pm.Normal("dv0_1", 0, 10), u.km / u.s)
    prior = tj.JokerSB2Prior.default(
        P_min=0.5*u.day, P_max=500*u.day,
        sigma_v=25*u.km/u.s,
        sigma_K0_1=30*u.km/u.s,
        sigma_K0_2=30*u.km/u.s,
        v0_offsets=None,
    )

# %%
joker = tj.TheJokerSB2(prior)

# %%
prior_samples, _ = prior.sample(size=1_000)

# %%
data = datas.copy()

# %%
#joker_helper = joker._make_joker_helper(datas)  # also validates data
from thejoker.likelihood_helpers import rejection_sample_inmem                                                                              
from thejoker.multiproc_helpers import rejection_sample_helper
from thejoker.data_helpers import validate_prepare_data
from thejoker.thejoker_sb2 import validate_prepare_data_sb2

all_data, ids, M = validate_prepare_data_sb2(          
    data, joker.prior.poly_trend, t_ref=data['1'].t_ref)

# %%
M.shape[0]

# %%
joker_helper.

# %%
from thejoker.thejoker_sb2 import CJokerSB2Helper
joker_helper = CJokerSB2Helper(all_data, joker.prior, M)
# Out:
# lijiao test self.n_times = 8
# lijiao

# %%
pwd
# Out:
# '/nfsdata/users/lijiao/Documents/thejoker_imac/thejoker/docs/examples'

# %%
dir(joker_helper)
# Out:
# ['A',
#  'Ainv',
#  'B',
#  'Binv',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'a',
#  'b',
#  'batch_get_posterior_samples',
#  'batch_marginal_ln_likelihood',
#  'data',
#  'internal_units',
#  'packed_order',
#  'prior',
#  'test_likelihood_worker']

# %%
joker_helper = CJokerSB2Helper(all_data, thejoker.prior, M) 
#if isinstance(prior_samples, int):
#    # If an integer, generate that many prior samples first
#    N = prior_samples
#    prior_samples = self.prior.sample(size=N, return_logprobs=return_logprobs)
#if in_memory:
#    if isinstance(prior_samples, JokerSamples):
#        ln_prior = None
#        if return_logprobs:
#            ln_prior = prior_samples["ln_prior"]
#        prior_samples, _ = prior_samples.pack(
#            units=joker_helper.internal_units, names=joker_helper.packed_order
#        )
#    else:
#        ln_prior = return_logprobs
#    samples = rejection_sample_inmem(
#        joker_helper,
#        prior_samples,
#        rng=self.rng,
#        ln_prior=ln_prior,
#        max_posterior_samples=max_posterior_samples,
#        n_linear_samples=n_linear_samples,
#        return_all_logprobs=return_all_logprobs,
#    )
#else:
#    samples = rejection_sample_helper(
#        joker_helper,
#        prior_samples,
#        pool=self.pool,
#        rng=self.rng,
#        n_prior_samples=n_prior_samples,
#        max_posterior_samples=max_posterior_samples,
#        n_linear_samples=n_linear_samples,
#        return_logprobs=return_logprobs,
#        n_batches=n_batches,
#        randomize_prior_order=randomize_prior_order,
#        return_all_logprobs=return_all_logprobs,
#    )

# %%
samples = joker.rejection_sample(datas, prior_samples, max_posterior_samples=1000)
samples
# Out:
# lijiao test self.n_pars = len(prior.par_names)
# lijiao test self.s_ivar = np.zeros(self.n_times, dtype=
# lijiao test line self.fixed_K_prior
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 samples = joker.rejection_sample(datas, prior_samples, max_posterior_samples=1000)
#       2 samples
#
# File ~/lijiao/anaconda3_20240201/lib/python3.11/site-packages/thejoker/thejoker.py:246, in TheJoker.rejection_sample(self, data, prior_samples, n_prior_samples, max_posterior_samples, n_linear_samples, return_logprobs, return_all_logprobs, n_batches, randomize_prior_order, in_memory)
#     234     samples = rejection_sample_inmem(
#     235         joker_helper,
#     236         prior_samples,
#    (...)
#     242         SamplesCls=self._samples_cls, # modified by lijiao
#     243     )
#     245 else:
# --> 246     samples = rejection_sample_helper(
#     247         joker_helper,
#     248         prior_samples,
#     249         pool=self.pool,
#     250         rng=self.rng,
#     251         n_prior_samples=n_prior_samples,
#     252         max_posterior_samples=max_posterior_samples,
#     253         n_linear_samples=n_linear_samples,
#     254         return_logprobs=return_logprobs,
#     255         n_batches=n_batches,
#     256         randomize_prior_order=randomize_prior_order,
#     257         return_all_logprobs=return_all_logprobs,
#     258         SamplesCls=self._samples_cls, # modified by lijiao
#     259     )
#     261 return samples
#
# File ~/lijiao/anaconda3_20240201/lib/python3.11/site-packages/thejoker/utils.py:290, in tempfile_decorator.<locals>.wrapper(*args, **kwargs)
#     288     func_return = func(*args, **kwargs)
#     289 except Exception as e:
# --> 290     raise e
#     291 finally:
#     292     os.unlink(f.name)
#
# File ~/lijiao/anaconda3_20240201/lib/python3.11/site-packages/thejoker/utils.py:288, in tempfile_decorator.<locals>.wrapper(*args, **kwargs)
#     286     prior_samples.write(f.name, overwrite=True)
#     287     kwargs["prior_samples_file"] = f.name
# --> 288     func_return = func(*args, **kwargs)
#     289 except Exception as e:
#     290     raise e
#
# File ~/lijiao/anaconda3_20240201/lib/python3.11/site-packages/thejoker/multiproc_helpers.py:269, in rejection_sample_helper(joker_helper, prior_samples_file, pool, rng, n_prior_samples, max_posterior_samples, n_linear_samples, return_logprobs, n_batches, randomize_prior_order, return_all_logprobs, SamplesCls)
#     266     full_samples_idx = good_samples_idx
#     268 # generate linear parameters
# --> 269 samples = make_full_samples(
#     270     joker_helper,
#     271     prior_samples_file,
#     272     pool,
#     273     rng,
#     274     full_samples_idx,
#     275     n_linear_samples=n_linear_samples,
#     276     n_batches=n_batches,
#     277     SamplesCls=SamplesCls # modified by lijiao
#     278 )
#     280 if return_logprobs:
#     281     samples["ln_likelihood"] = lls[good_samples_idx]
#
# File ~/lijiao/anaconda3_20240201/lib/python3.11/site-packages/thejoker/multiproc_helpers.py:161, in make_full_samples(joker_helper, prior_samples_file, pool, rng, samples_idx, n_linear_samples, n_batches, SamplesCls)
#     150 def make_full_samples(
#     151     joker_helper,
#     152     prior_samples_file,
#    (...)
#     158     SamplesCls=None # modified by lijiao
#     159 ):
#     160     task_args = (prior_samples_file, joker_helper, n_linear_samples)
# --> 161     results = run_worker(
#     162         make_full_samples_worker,
#     163         pool,
#     164         prior_samples_file,
#     165         task_args=task_args,
#     166         n_batches=n_batches,
#     167         samples_idx=samples_idx,
#     168         rng=rng,
#     169     )
#     171     # Concatenate all of the raw samples arrays
#     172     raw_samples = np.concatenate(results)
#
# File ~/lijiao/anaconda3_20240201/lib/python3.11/site-packages/thejoker/multiproc_helpers.py:57, in run_worker(worker, pool, prior_samples_file, task_args, n_batches, n_prior_samples, samples_idx, rng)
#      54         tasks[i] = tuple(tasks[i]) + (Generator(PCG64(sg[i])),)
#      56 results = []
# ---> 57 for res in pool.map(worker, tasks):
#      58     results.append(res)
#      60 return results
#
# File ~/lijiao/anaconda3_20240201/lib/python3.11/site-packages/thejoker/multiproc_helpers.py:143, in make_full_samples_worker(task)
#     141 if batch.dtype != np.float64:
#     142     batch = batch.astype(np.float64)
# --> 143 raw_samples, _ = joker_helper.batch_get_posterior_samples(
#     144     batch, n_linear_samples, rng
#     145 )
#     147 return raw_samples
#
# File ~/lijiao/anaconda3_20240201/lib/python3.11/site-packages/thejoker/src/fast_likelihood.pyx:779, in thejoker.src.fast_likelihood.CJokerSB2Helper.batch_get_posterior_samples()
#
# File ~/lijiao/anaconda3_20240201/lib/python3.11/site-packages/thejoker/src/fast_likelihood.pyx:865, in thejoker.src.fast_likelihood.CJokerSB2Helper.batch_get_posterior_samples()
#
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)

# %%
joker.prior.n_offsets

# %%
np.median(samples['P']), truth1['P'], np.percentile(samples['P'], [16, 50, 84]), np.std(samples['P'])

# %%
plt.scatter(samples['P'], samples['e'])
plt.xscale('log')
plt.xlim(1, 1e3)
plt.ylim(0, 1)

plt.xlabel('Period (d)')
plt.ylabel(r'$e$')
# Out:
# Text(0, 0.5, '$e$')

# %%
# %matplotlib inline
_ = plt.hist(samples['P'].value, bins=np.arange(0, 500, 1))

# %%
plt.scatter(samples['P'], samples['e'])
plt.xscale('log')
plt.xlim(1, 1e3)
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
tgrid = np.linspace(t0.mjd, t0.mjd + 5*truth1['P'].value, 4096)

fig, ax = plt.subplots()
_ = tj.plot_rv_curves(data=datas['1'], samples=samples.primary,
                      data_plot_kwargs=dict(color='tab:blue'),
                      plot_kwargs=dict(color='tab:blue'),
                      t_grid=tgrid, ax=ax)
ax.set_xlim(t0.mjd, t0.mjd + 5*truth1['P'].value)
ax.set_ylim(-75, 75)


fig, ax = plt.subplots()
_ = tj.plot_rv_curves(data=datas['2'], samples=samples.secondary, 
                      data_plot_kwargs=dict(color='tab:red'),
                      plot_kwargs=dict(color='tab:red'),
                      t_grid=tgrid, ax=ax)

ax.set_xlim(t0.mjd, t0.mjd + 5*truth1['P'].value)
ax.set_ylim(-75, 75)
# Out:
# (-75, 75)

# %% [markdown]
# ### Custom prior:

# %%
from thejoker.prior import default_nonlinear_prior
from thejoker.prior_sb2 import default_linear_prior_sb2
import exoplanet.units as xu

# %%
v0, ev0 = (1., 0.5)
p, ep = (5., 0.1)

with pm.Model() as model:
    v = xu.with_unit(pm.Normal('v0',v0, ev0), u.km/u.s)
    P = xu.with_unit(pm.Normal('P', p, ep), u.day)
    e = xu.with_unit(pm.Normal('e', 0, 0.01),u.one)
    default_nonlinear_prior(pars={'P': P,'e':e})
    default_linear_prior_sb2(sigma_K0_1=30*u.km/u.s,
                             P0_1=1*u.day,
                             sigma_K0_2=30*u.km/u.s,
                             P0_2=1*u.day,
                             pars={'v0': v})
